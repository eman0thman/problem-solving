# %% [markdown]
# **lecture** **02**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a= int(input("enter the first number: "))
b= int(input("enter the second number: "))
def sumation(a,b):
  return a + b

print(sumation(a,b))

# another solution
sumationn= lambda c, d: c + d
print(sumation(1,2))
# Out:
# enter the first number: 1
# enter the second number: 2
# 3
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number= int(input("Enter the numder: "))
for i in range(number):
  print(i)
  i -= 1
# Out:
# Enter the numder: 7
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i= int(input("Enter the numder: "))
while i < 1000:
  num= i*2
  print(num)
  i+=i
# Out:
# Enter the numder: 10
# 20
# 40
# 80
# 160
# 320
# 640
# 1280

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number= int(input("enter a number: "))
def seq(number):
  return number**2
print(seq(number))
# Out:
# enter a number: 2
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number= int(input("enter a number: "))
if number > 10:
  print("Big number")
else:
  print("small number")
# Out:
# enter a number: 10
# small number

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input("enter a: "))
b = int(input("enter b: "))
def productt(a,b):
  return a*b
print(productt(a,b))
# Out:
# enter a: 2
# enter b: 3
# 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number= int(input("enter a number: "))
while number > 0:
  number-=5
  print(number)
# Out:
# enter a number: 20
# 15
# 10
# 5
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num = int(input("Enter a number: "))
factorial = 1
for i in range(1, num + 1):
    factorial *= i
print(f"The factorial is: {factorial}")
# Out:
# Enter a number: 4
# The factorial is: 24

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number= int(input("enter a number: "))
if number > 0:
  print("Positive")
elif number < 0:
  print("Negative")
else:
  print("Zero")
# Out:
# enter a number: 10
# Positive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
divition = lambda a,b: a/b
print(divition(9,3))
# Out:
# 3.0
