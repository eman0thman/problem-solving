# %% [markdown]
# # **lecture 01**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#create
int_number= 1
float_number= 1.777
boolean= True
string= "python"

#print their type
print(type(int_number))
print(type(float_number))
print(type(boolean))
print(type(string))

#update their values
int_number= 3
float_number= 2.7
boolean= False
string= "Hello world"

#delete
del int_number
del float_number
del boolean
del string
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num1= int(input("enter the first number: "))
num2= int(input("enter the second number: "))
sum= print(num1 + num2)
difference= print(num1 - num2)
product= print(num1 * num2)
quotient= print(num1 / num2)
reminder= print(num1 % num2)
# Out:
# enter the first number: 9
# enter the second number: 3
# 12
# 6
# 27
# 3.0
# 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
boolean1= float(input("enter the first boolean: "))
boolean2= float(input("enter the second boolean: "))
boolean1= bool(boolean1)
boolean2= bool(boolean2)
print(boolean1 and boolean2)
print(boolean1 or boolean2)
print(not boolean1)
print(not boolean2)
# Out:
# enter the first boolean: 0
# enter the second boolean: 1
# False
# True
# True
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name=input("Enter your name= ")
age=int(input("Enter your age= "))
to_reach= 100-age
print(f"there are {to_reach} years you have until you turn 100 ")
# Out:
# Enter your name= eman
# Enter your age= 22
# there are 78 years you have until you turn 100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name= input("Enter your name: ")
fav_food= input("Enter your favorite food: ")
print(f"{name} likes {fav_food}")
# Out:
# Enter your name: eman
# Enter your favorite food: fruits
# eman likes fruits
